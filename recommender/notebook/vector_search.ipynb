# %% [markdown]
# # 2. Vector Search

# %%
from google.colab import drive

drive.mount('/content/drive')

# Save cleaned dataset to Google Drive (G: drive mapping)
moviez_dataset.to_csv('/content/drive/MyDrive/cleaned_moviez_dataset.csv', index=False)
