# %% [markdown]
# <a href="https://colab.research.google.com/github/lilswapnil/moviez/blob/main/recommender/notebook/vector_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Vector Search

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# Define the path where you saved the file in Google Drive
drive_path = '/content/drive/MyDrive/cleaned_moviez_dataset.csv'

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(drive_path)

# Display the first few rows to verify
print(f"Successfully loaded 'cleaned_moviez_dataset.csv' from Google Drive. Shape: {df.shape}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Successfully loaded 'cleaned_moviez_dataset.csv' from Google Drive. Shape: (8199, 7)

# %%
df
# Out:
#           id             original_title  \
# 0      27205                  Inception
# 1     157336               Interstellar
# 2        155            The Dark Knight
# 3      19995                     Avatar
# 4      24428               The Avengers
# ...      ...                        ...
# 8194  273169  Sous les jupes des filles
# 8195   43939             I'm Still Here
# 8196   15014                     Bianca
# 8197  652004    The Wolf of Snow Hollow
# 8198   94047                       마이웨이
#
#                                                overview  popularity  \
# 0     Cobb, a skilled thief who commits corporate es...      83.952
# 1     The adventures of a group of explorers who mak...     140.241
# 2     Batman raises the stakes in his war on crime. ...     130.643
# 3     In the 22nd century, a paraplegic Marine is di...      79.932
# 4     When an unexpected enemy emerges and threatens...      98.082
# ...
